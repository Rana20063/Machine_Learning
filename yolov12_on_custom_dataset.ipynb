# %% [markdown]
# <a href="https://colab.research.google.com/github/Rana20063/Transformer-LLearning/blob/main/yolov12_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# app.py	docker	  LICENSE  mkdocs.yml	   README.md	     tests
# assets	examples  logs	   pyproject.toml  requirements.txt  ultralytics

# %%
# !git clone https://github.com/sunsmarterjie/yolov12.git
# %cd yolov12
# Out:
# Cloning into 'yolov12'...
# remote: Enumerating objects: 1169, done.
# remote: Counting objects: 100% (569/569), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 1169 (delta 484), reused 433 (delta 433), pack-reused 600 (from 2)
# Receiving objects: 100% (1169/1169), 1.90 MiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (523/523), done.
# /content/yolov12/yolov12/yolov12

# %%
# !wget https://github.com/Dao-AILab/flash-attention/releases/download/v2.7.3/flash_attn-2.7.3+cu11torch2.2cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# Out:
# --2026-03-07 22:40:28--  https://github.com/Dao-AILab/flash-attention/releases/download/v2.7.3/flash_attn-2.7.3+cu11torch2.2cxx11abiFALSE-cp311-cp311-linux_x86_64.whl
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# ERROR: flash_attn-2.7.3+cu11torch2.2cxx11abiFALSE-cp311-cp311-linux_x86_64.whl is not a supported wheel on this platform.
# Obtaining file:///content/yolov12/yolov12/yolov12
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.63-0.editable-py3-none-any.whl size=20189 sha256=a4d6ccc3693368ee6cb1856ded7ff308e7d0d6645aa6e8ca70bfe0af374a2160
#   Stored in directory: /tmp/pip-ephem-wheel-cache-buewvriv/wheels/1f/8e/41/925b933bd5b26cc23940f9e1cfe083279902e4280be3361a8c
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.63
#     Uninstalling ultralytics-8.3.63:
#       Successfully uninstalled ultralytics-8.3.63
# ...

# %%
# !cat /content/drive/MyDrive/data/yolov12/datasets/license_plate_dataset/license_plate.yaml
# Out:
# cat: /content/drive/MyDrive/data/yolov12/datasets/license_plate_dataset/license_plate.yaml: No such file or directory

# %%
# !cp -r /content/drive/MyDrive/data/yolov12/datasets/license_plate_dataset  /content/yolov12
# Out:
# cp: cannot stat '/content/drive/MyDrive/data/yolov12/datasets/license_plate_dataset': No such file or directory

# %%
# !ls /content/yolov12/license_plate_dataset
# Out:
# ls: cannot access '/content/yolov12/license_plate_dataset': No such file or directory

# %%
from ultralytics import YOLO

model = YOLO('yolov12n.yaml')

# Train the model
results = model.train(
  data='/content/yolov12/license_plate_dataset/license_plate.yaml',
  epochs=20,
  batch=64,
  imgsz=640,
  scale=0.5,  # S:0.9; M:0.9; L:0.9; X:0.9
  mosaic=1.0,
  mixup=0.0,  # S:0.05; M:0.15; L:0.15; X:0.2
  copy_paste=0.1,  # S:0.15; M:0.4; L:0.5; X:0.6
  device="0",
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/yolov12/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# FlashAttention is not available on this device. Using scaled_dot_product_attention instead.
# New https://pypi.org/project/ultralytics/8.3.101 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.2.2+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("./runs/detect/train/weights/best.pt")
results = model("/content/drive/MyDrive/data/yolov12/datasets/license_plate_dataset/test/images/car-image2.jpg")
results[0].show()
